# %%
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FixedFormatter, AutoLocator, AutoMinorLocator, MaxNLocator,Locator,TickHelper
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fig,ax = plt.subplots(figsize=(12,9))
ax.plot(np.arange(2000, 2010), range(10))

# %%
ax.get_xaxis().get_major_formatter().set_useOffset(False)
fig

# %%
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(np.random.uniform(size=10))

# %%
tic.AutoLocator().set_axis(ax)
fig

# %%
def auto_xticklabels(ax, fontdict=None, nbins='auto', steps=None, **kwargs):
    if fontdict is None:
        fontdict={'fontweight': 'bold'}
    if steps is None:
        steps = [1, 2, 2.5, 5, 10]
    locator = MaxNLocator(nbins=nbins, **kwargs)
    locator.set_axis(ax.xaxis)
    ax.set_xticks(locator())
    ax.set_xticklabels(locator(), fontdict=fontdict)
def auto_yticklabels(ax, fontdict=None, nbins='auto', steps=None, **kwargs):
    if fontdict is None:
        fontdict={'fontweight': 'bold'}
    if steps is None:
        steps = [1, 2, 2.5, 5, 10]
    locator = MaxNLocator(**kwargs)
    locator.set_axis(ax.yaxis)
    ax.set_yticks(locator())
    ax.set_yticklabels(locator(), fontdict=fontdict)
    
def legend(ax, **kwargs):
    #l = ax.legend(**kwargs)
    l = ax.legend(**kwargs)
    l.get_title().set_fontweight('bold')
    l.get_title().set_fontsize(12)
    return l

# %%
fig, ax = plt.subplots(figsize=(12, 9))
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(np.pi*x), label='sin(x)', linewidth=1.5)
ax.plot(x, np.cos(np.pi*x), label='cos(y)', linewidth=1.5)
#ax.set_xlabel('xlabel')
#ax.set_ylabel('ylabel')
#ax.spines['top'].set_visible(False)
#ax.spines['right'].set_visible(False)

#ax.set_title('Font size demo')
#legend(ax, title='Curve', bbox_to_anchor=(1.04,0.5), loc="center left", borderaxespad=0)
fontdict=None
nbins='auto'
steps=None
if fontdict is None:
    fontdict={'fontweight': 'bold'}
if steps is None:
    steps = [1, 2, 2.5, 5, 10]
locator = MaxNLocator(nbins=5, fontdict=fontdict)
locator.set_axis(ax.xaxis)
ax.set_xticks(locator())
ax.set_xticklabels(locator(), fontdict=fontdict)
#auto_xticklabels(ax)
#auto_yticklabels(ax)
#ax.xaxis.set_major_locator(MaxNLocator(5))
# Out:
# [Text(0, 0, '-3.0'),
#  Text(0, 0, '0.0'),
#  Text(0, 0, '3.0'),
#  Text(0, 0, '6.0'),
#  Text(0, 0, '9.0'),
#  Text(0, 0, '12.0'),
#  Text(0, 0, '15.0')]

# %%
isinstance(2, matplotlib.ticker.Locator)
# Out:
# False

# %%
list(ax.yaxis.get_majorticklabels())
# Out:
# [Text(0, -1.25, '-1.25'),
#  Text(0, -1.0, '-1.0'),
#  Text(0, -0.75, '-0.75'),
#  Text(0, -0.5, '-0.5'),
#  Text(0, -0.25, '-0.25'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.25, '0.25'),
#  Text(0, 0.5, '0.5'),
#  Text(0, 0.75, '0.75'),
#  Text(0, 1.0, '1.0'),
#  Text(0, 1.25, '1.25')]

# %%
MaxNLocator(nbins='auto').view_limits(1.5,9)
# Out:
# (1.5, 9)

# %%
fig

# %%
vars(ax)
# Out:
# {'figure': <Figure size 864x648 with 1 Axes>,
#  '_subplotspec': <matplotlib.gridspec.SubplotSpec at 0x7faf480a7048>,
#  'figbox': Bbox([[0.125, 0.125], [0.9, 0.88]]),
#  'rowNum': 0,
#  'colNum': 0,
#  'numRows': 1,
#  'numCols': 1,
#  '_stale': True,
#  'stale_callback': <function matplotlib.figure._stale_figure_callback(self, val)>,
#  '_axes': <matplotlib.axes._subplots.AxesSubplot at 0x7faf480a7550>,
#  '_transform': None,
#  '_transformSet': False,
#  '_visible': True,
#  '_animated': False,
#  '_alpha': None,
#  'clipbox': None,
#  '_clippath': None,
#  '_clipon': True,
#  '_label': '',
#  '_picker': None,
#  '_contains': None,
#  '_rasterized': None,
#  '_agg_filter': None,
#  '_mouseover': False,
#  'eventson': False,
#  '_oid': 0,
#  '_propobservers': {},
#  '_remove_method': <bound method Figure._remove_ax of <Figure size 864x648 with 1 Axes>>,
#  '_url': None,
#  '_gid': None,
#  '_snap': None,
#  '_sketch': None,
#  '_path_effects': [],
#  '_sticky_edges': _XYPair(x=[], y=[]),
#  '_in_layout': True,
#  '_position': Bbox([[0.125, 0.125], [0.9, 0.88]]),
#  '_originalPosition': Bbox([[0.125, 0.125], [0.9, 0.88]]),
#  '_aspect': 'auto',
#  '_adjustable': 'box',
#  '_anchor': 'C',
#  '_sharex': None,
#  '_sharey': None,
#  'bbox': <matplotlib.transforms.TransformedBbox at 0x7faf480b20f0>,
#  'dataLim': Bbox([[0.0, -0.9999987638285974], [10.0, 1.0]]),
#  'viewLim': Bbox([[-1.5, -1.25], [10.5, 1.25]]),
#  'transScale': <matplotlib.transforms.TransformWrapper at 0x7faf480b2f28>,
#  'transAxes': <matplotlib.transforms.BboxTransformTo at 0x7faf480b2710>,
#  'transLimits': <matplotlib.transforms.BboxTransformFrom at 0x7faf480b2860>,
#  'transData': <matplotlib.transforms.CompositeGenericTransform at 0x7faf480b2e10>,
#  '_xaxis_transform': <matplotlib.transforms.BlendedGenericTransform at 0x7faf480b2b70>,
#  '_yaxis_transform': <matplotlib.transforms.BlendedGenericTransform at 0x7faf480b2c18>,
#  '_axes_locator': None,
#  'spines': OrderedDict([('left', <matplotlib.spines.Spine at 0x7faf481712e8>),
#               ('right', <matplotlib.spines.Spine at 0x7faf48171eb8>),
#               ('bottom', <matplotlib.spines.Spine at 0x7faf48171320>),
#               ('top', <matplotlib.spines.Spine at 0x7faf48171940>)]),
#  'xaxis': <matplotlib.axis.XAxis at 0x7faf480b2ef0>,
#  'yaxis': <matplotlib.axis.YAxis at 0x7faf48171a20>,
#  '_facecolor': 'white',
#  '_frameon': True,
#  '_axisbelow': 'line',
#  '_rasterization_zorder': None,
#  '_connected': {},
#  'ignore_existing_data_limits': False,
#  'callbacks': <matplotlib.cbook.CallbackRegistry at 0x7faf48171630>,
#  '_autoscaleXon': True,
#  '_autoscaleYon': True,
#  '_xmargin': 0.05,
#  '_ymargin': 0.05,
#  '_tight': None,
#  '_use_sticky_edges': True,
#  '_get_lines': <matplotlib.axes._base._process_plot_var_args at 0x7faf4816a8d0>,
#  '_get_patches_for_fill': <matplotlib.axes._base._process_plot_var_args at 0x7faf4816a9b0>,
#  '_gridOn': False,
#  'lines': [<matplotlib.lines.Line2D at 0x7faf482a4668>,
#   <matplotlib.lines.Line2D at 0x7faf480a76a0>],
#  'patches': [],
#  'texts': [],
#  'tables': [],
#  'artists': [],
#  'images': [],
#  '_mouseover_set': <matplotlib.cbook._OrderedSet at 0x7faf467ee208>,
#  'child_axes': [],
#  '_current_image': None,
#  'legend_': <matplotlib.legend.Legend at 0x7faf48298860>,
#  'collections': [],
#  'containers': [],
#  'title': Text(0.5, 1.0, 'Font size demo'),
#  '_left_title': Text(0.0, 1.0, ''),
#  '_right_title': Text(1.0, 1.0, ''),
#  'titleOffsetTrans': <matplotlib.transforms.ScaledTranslation at 0x7faf4816af60>,
#  '_autotitlepos': True,
#  'patch': <matplotlib.patches.Rectangle at 0x7faf480edac8>,
#  'axison': True,
#  'fmt_xdata': None,
#  'fmt_ydata': None,
#  '_cachedRenderer': <matplotlib.backends.backend_agg.RendererAgg at 0x7faf483084a8>,
#  '_navigate': True,
#  '_navigate_mode': None,
#  '_xcid': 0,
#  '_ycid': 0,
#  '_layoutbox': None,
#  '_poslayoutbox': None}

# %%
mylist = [1,2,4,4,5,6]
mylist
# Out:
# [1, 2, 4, 4, 5, 6]

# %%
[i for i in set(mylist)]
# Out:
# [1, 2, 4, 5, 6]

# %%
i = True
if i is True:
    print("123")
# Out:
# 123
