# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import seaborn as sns
from IPython.display import HTML, display, FileLink
sns.set_style('white')
from wand.image import Image as WImage
from wand.display import display as wdisplay
from matplotlib.ticker import FixedFormatter, AutoLocator, AutoMinorLocator, MaxNLocator

# %%
paper_dpi = 300
screen_dpi = 220
paper_size = (9, 7)

def to_paper_size(width, height):
    #return width/2.54*screen_dpi/paper_dpi, height/2.54*screen_dpi/paper_dpi
    return width/7.02, height/7.02

def to_paper_size_pdf(width, height):
    '''Convert PPT size in cm to figsize in inch
    '''
    return width/2.54, height/2.54

def cm_to_inch(width, height):
    return width/2.54, height/2.54

def to_screen_size(width, height):
    return width*7.02, height*7.02

def to_paper_font(x):
    #return x*18/49
    return x

def image_link(filename):
    plt.savefig(filename)
    display(WImage(filename=filename))
    plt.close()
    display(FileLink(filename))

def auto_xticklabels(ax, fontdict=None, nbins='auto', steps=None, **kwargs):
    if fontdict is None:
        fontdict={'fontweight': 'bold'}
    if steps is None:
        steps = [1, 2, 2.5, 5, 10]
    locator = MaxNLocator(nbins=nbins, **kwargs)
    locator.set_axis(ax.xaxis)
    ax.set_xticks(locator())
    ax.set_xticklabels(locator(), fontdict=fontdict)
    
def auto_yticklabels(ax, fontdict=None, nbins='auto', steps=None, **kwargs):
    if fontdict is None:
        fontdict={'fontweight': 'bold'}
    if steps is None:
        steps = [1, 2, 2.5, 5, 10]
    locator = MaxNLocator(**kwargs)
    locator.set_axis(ax.yaxis)
    ax.set_yticks(locator())
    ax.set_yticklabels(locator(), fontdict=fontdict)
    
def legend(ax, **kwargs):
    l = ax.legend(**kwargs)
    l.get_title().set
    l.get_title().set_fontweight('bold')
    l.get_title().set_fontsize(12)
    return l

def plot_demo():
    x = np.linspace(0, 10, 1000)
    fig, ax = plt.subplots(figsize=cm_to_inch(12, 9))
    ax.plot(x, np.sin(np.pi*x), label='sin(x)', linewidth=1.5)
    ax.plot(x, np.cos(np.pi*x), label='cos(y)', linewidth=1.5)
    ax.set_xlabel('xlabel')
    ax.set_ylabel('ylabel')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    auto_xticklabels(ax)
    auto_yticklabels(ax)
    ax.set_ylim(-1, 1)
    ax.set_xlim(0, 10)
    
    ax.set_title('Font size demo')
    legend(ax, title='Curve', bbox_to_anchor=(1.04,0.5), loc="center left", borderaxespad=0)
    fig.tight_layout()
    image_link('demo.pdf')


screen_size = paper_size[0]*2.54, paper_size[1]*2.54
example_figsize = (10, 10)
print('paper size = {} x {} in'.format(*paper_size))
print('paper DPI = {}'.format(paper_dpi))
print('screen size = {:.2f} x {:.2f} cm'.format(*screen_size))
print('figsize in screen = {} x {} cm'.format(*example_figsize))
print('figsize in paper = {:.2f} x {:.2f} in'.format(*to_paper_size(*example_figsize)))

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 10
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['xtick.major.size'] = 5
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['ytick.major.size'] = 5
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['legend.fontsize'] = 12
plt.rcParams['xtick.bottom'] = True
plt.rcParams['ytick.left'] = True
plt.rcParams['axes.linewidth'] = 1.0
plt.rcParams['patch.linewidth'] = 1.0

fontsize_params = ['font.size',
    'axes.titlesize', 'axes.labelsize',
    'xtick.major.size', 'xtick.minor.size', 'xtick.labelsize',
    'ytick.major.size', 'ytick.minor.size', 'ytick.labelsize',
    'legend.fontsize', 'figure.titlesize',
    'figure.figsize', 'ps.papersize', 'figure.dpi'
]
#for param in fontsize_params:
#    print(param, '=', plt.rcParams[param])

plot_demo()
# Out:
# paper size = 9 x 7 in
# paper DPI = 300
# screen size = 22.86 x 17.78 cm
# figsize in screen = 10 x 10 cm
# figsize in paper = 1.42 x 1.42 in
# <wand.image.Image: 1024a8e 'PDF' (340x255)>
# /Share/home/shibinbin/projects/exSeek-dev/jupyter/demo.pdf

# %%
fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(np.random.uniform(size=10))
AutoLocator().set_axis(ax)

# %%
locator = MaxNLocator(nbins=7)
locator.set_axis(ax.xaxis)
locator()
# Out:
# array([-1.5,  0. ,  1.5,  3. ,  4.5,  6. ,  7.5,  9. , 10.5])

# %%
fig, ax = plt.subplots()
ax.plot(np.arange(10), label='1')
l = ax.legend(title='ABCD')
l.get_title().set_fontweight('bold')
l.get_title().set_fontsize(16)
ax.get_legend()
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fae31973730> (for post_execute):
# /apps/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['fontsize'] not found. Falling back to DejaVu Sans
#   if result is None:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /apps/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in post_execute()
#     147        display hook this will reset ``sys.displayhook`` to what ever
#     148        function was there when matplotlib installed it's displayhook,
# --> 149        possibly discarding your changes.
#     150     """
#     151     global _IP_REGISTERED
#
# /apps/anaconda3/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     134 atexit.register(Gcf.destroy_all)
#
# ...

# %%
matplotlib.colors.to_hex(sns.color_palette('deep', 10)[0])
# Out:
# '#4c72b0'

# %%
sns.palplot(sns.color_palette('deep', 10))

# %%
sns.palettes.cubehelix_palette
# Out:
# <module 'seaborn.palettes' from '/apps/anaconda3/lib/python3.6/site-packages/seaborn/palettes.py'>

# %%
sns.color_palette('vlag')
# Out:
# [(0.4305964, 0.56276546, 0.74956387),
#  (0.66563334, 0.72242871, 0.81414642),
#  (0.89443865, 0.89721298, 0.9202854),
#  (0.94742246, 0.87278899, 0.86691076),
#  (0.85164413, 0.65142189, 0.64145983),
#  (0.76133542, 0.43410655, 0.42592523)]
