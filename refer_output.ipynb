# %%
library(magrittr)

# %%
cv_fun <- function(x) {
	sd(x, na.rm = T) / mean(x, na.rm = T)
}

# %%
norm_cpm_refer <- function(mat, refer_gene_id_path='data/matrix_processing/refer_gene_id.txt',cv_threshold=0.5) {
    print(paste('start normalization by reference gene ','thresholding reference gene by Coefficient of Variance:',args$cvthreshold,sep=' '))
    refer_gene_id <- read.table(refer_gene_id_path,check.names = FALSE)[,1]
    row_refer <- mat %>% rownames() %>% stringr::str_extract('[^|]+') %>%
    {. %in% refer_gene_id}
    if (!any(row_refer))
    stop('can\'t find any reference genes in the matrix for CPM normalization')
    keeped_ref <- mat[row_refer, , drop = F] %>% apply(1, cv_fun) < cv_threshold
    norm_cpm_impl(mat, row_refer[keeped_ref])
}

# %%
refer_gene_id <- read.table("/home/xieyufeng/exSeek/data/matrix_processing/refer_gene_tid.txt",check.names = FALSE)[,1]

# %%
refer_gene_id
# Out:
#  [1] ENSG00000221365.1 ENSG00000208006.1 ENSG00000283785.1 ENSG00000284565.1
#  [5] ENSG00000284190.1 ENSG00000207980.1 ENSG00000207779.1 ENSG00000198987.1
#  [9] ENSG00000207563.1 ENSG00000264566.3
# 10 Levels: ENSG00000198987.1 ENSG00000207563.1 ... ENSG00000284565.1

# %%
mat <- read.table("/home/xieyufeng/exSeek/data/transcript.txt",header = T, check.names = FALSE,row.names = 1)

# %%
mat
# Out:
#                                     Sample_1S3 Sample_1S6 Sample_1S9
# 10904|tRNA|10904                       1          8         11
# 12954|tRNA|12954                      20          9         13
# 12956|tRNA|12956                     189        227        187
# 12958|tRNA|12958                     823        706        771
# 12960|tRNA|12960                       0          2          1
# 12962|tRNA|12962                    7727       9819       6867
# 12964|tRNA|12964                      15         17         16
# 12965|tRNA|12965                     141        105        137
# 12967|tRNA|12967                     193        135        223
# 12969|tRNA|12969                     522        850        484
# 12971|tRNA|12971                       1          7          1
# 12973|tRNA|12973                       9          7          1
# 12975|tRNA|12975                     313        486        301
# 12977|tRNA|12977                       0          0          0
# ...

# %%
row_refer <- mat %>% rownames() %>% stringr::str_extract('[^|]+') %>% {. %in% refer_gene_id}

# %%
table(row_refer)
# Out:
# row_refer
# FALSE  TRUE
# 57203    10

# %%
any(row_refer)
# Out:
# [1] TRUE

# %%
mat[row_refer, , drop = F]
# Out:
#                                 Sample_1S3 Sample_1S6 Sample_1S9 Sample_1S12
# ENSG00000198987.1|miRNA|MIR16-2  1810       1854       1555       1433
# ENSG00000284190.1|miRNA|MIR21   41451      45392      34325      34982
# ENSG00000207563.1|miRNA|MIR23B    693        905        617        916
# ENSG00000207779.1|miRNA|MIR15B     24         51         11         25
# ENSG00000284565.1|miRNA|MIR451A  5172       4624       3085       5204
# ENSG00000207980.1|miRNA|MIR23A   2051       3251       1978       2472
# ENSG00000208006.1|miRNA|MIR16-1  1748       1579       1434       1408
# ENSG00000221365.1|miRNA|MIR1228     1          1          4          4
# ENSG00000264566.3|miRNA|MIR23C      0          2          0          1
# ENSG00000283785.1|miRNA|MIR15A     81         66         66         34
#                                 Sample_1S15 Sample_1S18 Sample_1S21 Sample_1S24
# ENSG00000198987.1|miRNA|MIR16-2  1300        1181        1910        2877
# ...

# %%
rownames(mat[row_refer, , drop = F])
# Out:
#  [1] "ENSG00000198987.1|miRNA|MIR16-2" "ENSG00000284190.1|miRNA|MIR21"
#  [3] "ENSG00000207563.1|miRNA|MIR23B"  "ENSG00000207779.1|miRNA|MIR15B"
#  [5] "ENSG00000284565.1|miRNA|MIR451A" "ENSG00000207980.1|miRNA|MIR23A"
#  [7] "ENSG00000208006.1|miRNA|MIR16-1" "ENSG00000221365.1|miRNA|MIR1228"
#  [9] "ENSG00000264566.3|miRNA|MIR23C"  "ENSG00000283785.1|miRNA|MIR15A"

# %%
write.table(mat[row_refer, , drop = F] %>% rownames() %>% stringr::str_extract('[^|]+'),"/home/xieyufeng/exSeek/data/matrix_processing/refer_output.txt",row.names = FALSE,col.names = FALSE,quote = FALSE)

# %%
refer_gene_id <- read.table("/home/xieyufeng/exSeek/data/matrix_processing/refer_gene_gid.txt",check.names = FALSE)[,1]

# %%
row_refer <- mat %>% rownames() %>% stringr::str_extract('[^|]+') %>% {. %in% refer_gene_id}

# %%
table(row_refer)
# Out:
# row_refer
# FALSE
# 57213

# %%
write.table(mat[row_refer, , drop = F] %>% rownames() %>% stringr::str_extract('[^|]+'),"/home/xieyufeng/exSeek/data/matrix_processing/refer_output_null.txt",row.names = FALSE,col.names = FALSE,quote = FALSE)
